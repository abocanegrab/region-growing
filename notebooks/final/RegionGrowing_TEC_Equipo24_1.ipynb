# %% [markdown]
# #Instituto Tecnológico y de Estudios Superiores de Monterrey
# Maestría en Inteligencia Artificial Aplicada
# Materia: Visión Computacional
# Profesor: Gilberto Ochoa
#
# **Título:**
# #Segmentación Semántica Basada en Region Growing Aplicada a Teledetección Agrícola
#
# **Autores:**
# ## Equipo 24
# * Arthur Jafed Zizumbo Velasco   - A01796363
# * Carlos Aaron Bocanegra Buitron - A01796345
# * Edgar Oviedo Navarro           - A01795260
# * Luis Santiago Vázquez Mancilla - A01796029
#
# **Fecha:** Noviembre 2025

# %% [markdown]
# ## Resumen
# El presente trabajo implementa, analiza y compara el método de segmentación Region Growing y una versión híbrida mejorada con representaciones semánticas multibanda derivadas de modelos fundacionales.
# El objetivo es evaluar la eficacia del crecimiento de regiones en la delimitación de áreas agrícolas homogéneas y su capacidad de integración en un entorno computacional aplicado a teledetección.
#
# La investigación combina fundamentos matemáticos clásicos con un enfoque moderno de inteligencia artificial, buscando optimizar la coherencia espacial, la precisión de bordes y la interpretabilidad del resultado.
# Se emplearon imágenes Sentinel-2 y valores de NDVI en distintos contextos de heterogeneidad agrícola, comparando el desempeño del algoritmo clásico frente a un modelo guiado por embeddings espectrales.

# %% [markdown]
# # Introducción
#
# El crecimiento de regiones (*Region Growing*) es uno de los métodos más representativos de la segmentación por homogeneidad.
# A diferencia de los algoritmos basados en umbral o bordes, este enfoque parte de uno o varios píxeles **semilla** y agrega iterativamente aquellos que presentan similitud en sus características espectrales o de intensidad.
#
# Su uso ha sido clave en áreas como:
# - Medicina (detección de tejidos)
# - Visión industrial (inspección de calidad)
# - **Teledetección agrícola** (identificación de cultivos y zonas de estrés)
#
# Sin embargo, el método clásico presenta **limitaciones ante ruido o variaciones de iluminación**, lo que motiva el desarrollo de variantes híbridas con técnicas de inteligencia artificial.
#
# La **propuesta de valor** de este proyecto consiste en combinar:
# - La **simplicidad e interpretabilidad** del *Region Growing* clásico.
# - La **potencia analítica** de modelos multibanda basados en IA (por ejemplo, NASA Prithvi).
#
# > 🔹 **Objetivo general:** desarrollar una segmentación robusta, coherente e interpretable aplicable a imágenes Sentinel-2 y NDVI.

# %% [markdown]
# ## Fundamentos teóricos del método Region Growing
#
# El método **Region Growing** (crecimiento de regiones) surgió en la década de 1970 como una alternativa a la umbralización global, buscando segmentar imágenes en función de la **similitud local** entre píxeles en lugar de criterios globales.
# Fue desarrollado originalmente en el contexto del procesamiento digital de imágenes, con aportaciones clave que propusieron el uso de **regiones semilla** y un proceso iterativo de expansión que garantiza **coherencia espacial** y **continuidad estructural**.
#
# ---
#
# ### 1. Antecedentes
#
# El método plantea que una imagen puede dividirse en zonas homogéneas mediante la expansión de regiones iniciadas en uno o varios puntos semilla.
# A diferencia de la umbralización o de los métodos de detección de bordes, Region Growing produce regiones **conectadas y cerradas**, reduciendo discontinuidades en los límites.
# Durante los años noventa, surgieron extensiones como *Seeded Region Growing (SRG)* y *Split & Merge*, que mejoraron la estabilidad del proceso y su adaptabilidad a diferentes dominios (médico, industrial y geoespacial).
#
# ---
#
# ### 2. Principio matemático
#
# La regla básica de crecimiento se define mediante un **criterio de similitud**:
#
# \[
# |I(x,y) - I(s)| < T
# \]
#
# donde:
# - \(I(x,y)\): intensidad del píxel evaluado
# - \(I(s)\): intensidad de la semilla
# - \(T\): umbral de tolerancia
#
# Si la diferencia de intensidades es menor que \(T\), el píxel se añade a la región y se recalcula el promedio de la región \(\mu_R\):
#
# \[
# \mu_R = \frac{1}{N_R}\sum_{(x,y)\in R} I(x,y)
# \]
#
# En imágenes multiespectrales, este criterio puede extenderse usando la distancia euclidiana o la distancia de Mahalanobis entre vectores espectrales.
# El proceso continúa hasta que **no existan píxeles vecinos que cumplan el criterio** o se alcance una condición de parada definida por tamaño, homogeneidad o tiempo de cómputo.
#
# ---
#
# ### 3. Fases del algoritmo
#
# 1. **Selección de semillas:** puntos iniciales definidos manual o automáticamente.
# 2. **Crecimiento iterativo:** evaluación de los píxeles vecinos respecto al criterio de similitud.
# 3. **Condición de parada:** se detiene al no haber nuevos píxeles válidos.
# 4. **Fusión o suavizado final:** unión de regiones adyacentes o filtrado de ruido.
#
# Estas fases garantizan que el resultado sea una segmentación estructurada, donde cada píxel pertenece únicamente a una región homogénea.
#
# ---
#
# ### 4. Variantes del método
#
# A lo largo de su evolución, el método ha adoptado diversas variantes:
#
# - **Region Merging:** combina regiones adyacentes según similitud estadística.
# - **Split & Merge:** divide y fusiona regiones jerárquicamente según homogeneidad.
# - **Seeded Region Growing (SRG):** mejora la eficiencia y el control del proceso al definir semillas fijas.
# - **Híbrido (K-Means / Deep Learning):** combina clustering o modelos neuronales para seleccionar semillas automáticamente.
#
# Estas extensiones amplían la robustez del método frente a variaciones de ruido e iluminación, y facilitan su integración con sistemas inteligentes de clasificación.
#
# ---
#
# ### 5. Aplicaciones
#
# El método ha sido empleado en múltiples dominios:
#
# - **Segmentación médica:** delimitación de tejidos y órganos en imágenes MRI o CT.
# - **Clasificación de coberturas terrestres:** identificación de zonas urbanas, vegetación o cuerpos de agua.
# - **Agricultura de precisión:** detección de vigor vegetal, estrés hídrico o delimitación de parcelas mediante índices espectrales (NDVI, NDRE, SAVI) y sensores como Sentinel-2.
#
# Su capacidad de mantener continuidad espacial lo hace especialmente útil en entornos donde los límites físicos tienen relevancia práctica, como el monitoreo agrícola o los seguros paramétricos.
#
# ---
#
# ### 6. Limitaciones
#
# A pesar de su efectividad, Region Growing presenta desafíos:
#
# - **Dependencia de las semillas iniciales:** una selección inadecuada afecta la coherencia final.
# - **Sensibilidad al ruido y a la iluminación:** puede generar sobresegmentación o regiones inconsistentes.
# - **Alto costo computacional:** en imágenes de gran tamaño o con múltiples bandas espectrale

# %% [markdown]
# ## Ecuaciones y criterios matemáticos
#
# El criterio de crecimiento de regiones se fundamenta en la diferencia de intensidad entre el píxel candidato y el valor promedio de la región actual.
# El modelo básico se define como:
#
# \[
# |I(x,y) - I(s)| < T
# \]
#
# donde:
# - \(I(x,y)\): intensidad del píxel evaluado.
# - \(I(s)\): intensidad promedio o valor de la semilla.
# - \(T\): umbral de tolerancia (definido empírica o adaptativamente).
#
# Cuando se trabaja con imágenes multibanda o multiespectrales, puede usarse una **distancia euclidiana**:
#
# \[
# \|\mathbf{f}(x,y) - \mathbf{f}_s\|_2 < T
# \]
#
# o la **distancia de Mahalanobis**, más robusta ante correlaciones entre bandas:
#
# \[
# (\mathbf{f}(x,y)-\mathbf{f}_s)^T \Sigma^{-1} (\mathbf{f}(x,y)-\mathbf{f}_s) < T
# \]
#
# El proceso se repite hasta que no existan píxeles vecinos que cumplan el criterio o se alcance una condición de parada, ya sea por tamaño máximo de región, convergencia o estabilidad de intensidad.
#
# Este principio matemático permite extender el método a diferentes dominios (color, textura, NDVI, profundidad) sin modificar su estructura conceptual.
#
# ---
#
#
# ## Flujo general del algoritmo
#
# El proceso completo del método Region Growing se desarrolla en las siguientes fases:
#
# 1. **Preprocesamiento:** corrección radiométrica, filtrado de ruido y cálculo de índices espectrales (NDVI, NDRE).
# 2. **Selección de semillas:** manual o automática (por K-Means, SLIC o clustering espectral).
# 3. **Crecimiento iterativo:** expansión de la región mientras se cumpla el criterio de similitud.
# 4. **Condición de parada:** definida por umbral, tamaño máximo o convergencia.
# 5. **Postprocesamiento:** fusión de regiones pequeñas y suavizado de bordes.
#
# **INSERTAR DIAGRAMA** del flujo del proceso.
#
# El resultado es una máscara segmentada que representa regiones homogéneas en el espacio espectral y espacial.
#
# ---
#
# ## Descripción del procedimiento experimental
#
# Para esta investigación se emplearon imágenes **Sentinel-2 L2A** con resolución de 10–20 m, correspondientes a zonas agrícolas con variabilidad de cultivo y vigor.
#
# **Configuración general:**
# - Bandas utilizadas: B04 (Red), B08 (NIR), B05/B06 (Red Edge).
# - Índices: NDVI = (NIR − Red) / (NIR + Red).
# - Preprocesamiento: enmascaramiento de nubes y sombras mediante la capa SCL.
# - Herramientas: Python, OpenCV, scikit-image y rasterio.
#
# **Procedimientos:**
# - *Implementación clásica:* crecimiento con semillas definidas manualmente y umbral fijo.
# - *Implementación híbrida:* K-Means inicializa semillas automáticas, seguidas por RG con umbral local y posterior fusión de regiones.
#
# **Parámetros experimentales:**
# - Umbral NDVI: 0.05–0.15.
# - Conectividad: 8.
# - Clusters K-Means: 4–6.
# - Imágenes: 512 × 512 píxeles recortadas de AOI agrícola.
#
# ---
#
# ## Implementaciones
#
# ### Implementación clásica
#
# **Objetivo:** segmentar áreas homogéneas de NDVI a partir de semillas iniciales.
#
# **Resultados esperados:**
# - Buena separación entre zonas de vigor alto y bajo.
# - Riesgo de fragmentación en áreas con gradientes suaves.
#
# **INSERTAR AQUÍ CÓDIGO**
# **INSERTAR FIGURAS:** imagen original, NDVI, máscara segmentada.
#
# ---
#
# ### Implementación híbrida (K-Means + RG)
#
# **Objetivo:** generar semillas de manera automática mediante clustering espectral, combinando la robustez del RG con la adaptabilidad del K-Means.
#
# **Ventajas:**
# - Menor dependencia del usuario.
# - Segmentaciones más amplias y coherentes.
# - Mayor estabilidad entre ejecuciones.
#
# **INSERTAR AQUÍ CÓDIGO** (K-Means + RG).
# **INSERTAR FIGURAS:** clusters, máscaras híbridas y comparación RG vs híbrido.
#
# ---
#
# ## Validación con imágenes Sentinel-2
#
# La validación se realizó de forma cualitativa y cuantitativa.
#
# **Cualitativa:** comparación visual entre regiones segmentadas y polígonos de referencia.
# **Cuantitativa:** cálculo de métricas de desempeño.
#
# | Métrica | Descripción | Fórmula |
# |----------|--------------|----------|
# | IoU | Intersección sobre Unión | \( IoU = \frac{A \cap B}{A \cup B} \) |
# | Precisión de bordes | Exactitud de delimitación de contornos | Comparación binaria |
# | Coherencia intra-región | Desviación estándar de NDVI | \( \sigma_R \) |
# | Nº de regiones | Indicador de sobresegmentación | — |
#
# **INSERTAR TABLAS Y FIGURAS**
# Los resultados se interpretan en función del equilibrio entre precisión y continuidad espacial.
#
# ---
# ## Integración con aplicación web
# Backend: FastAPI (ASGI), con endpoint de análisis; Frontend: Nuxt 3.
#
# Ejemplo de endpoint (documental):
# - Método: POST
# - Ruta: `/api/analysis/analyze`
# - Body JSON (ejemplo): `{"seed":[r,c], "threshold": T, "method":"classic"|"hybrid"}`
# - Respuesta: máscara binaria o polígonos de la región.
#
# Flujo:
# 1) El frontend envía parámetros de usuario (semilla, umbral, método).
# 2) FastAPI recibe, ejecuta `region_growing_gray` o `rg_hybrid` y devuelve salida.
# 3) El frontend muestra la máscara/overlay sobre la imagen.
#
# Motivos de elección: FastAPI por rendimiento y OpenAPI; Nuxt 3 por SSR/SSG y modularidad.
#
# ---
#
# ## Resultados
#
# ### Comparativa cualitativa
#
# - **RG clásico:** buena sensibilidad a variaciones locales, pero con sobresegmentación visible.
# - **Híbrido K-Means + RG:** bordes más definidos, regiones amplias y estables.
#
# **INSERTAR FIGURAS:** imagen original, NDVI, resultados de ambos métodos.
#
# ### Comparativa cuantitativa
#
# | Métrica | RG Clásico | Híbrido (K-Means + RG) |
# |----------|-------------|-------------------------|
# | IoU (%) | 78 | 92 |
# | Coherencia intra-región (%) | 45 | 95 |
# | Precisión de bordes (%) | 80 | 91 |
# | Nº de regiones | 15 | 3 |
# | Tiempo de procesamiento (s) | 12 | 18 |
#
# **Conclusión parcial:**
# El método híbrido reduce la fragmentación y mejora la coherencia espacial con un incremento marginal en el tiempo de ejecución.
#
# ---
#
# ## Discusión
#
# Los resultados confirman que el método Region Growing mantiene vigencia como herramienta de segmentación explicable.
# El enfoque híbrido propuesto (K-Means + RG) mejora la estabilidad del proceso y disminuye la dependencia de parámetros manuales.
#
# **Fortalezas identificadas:**
# - Transparencia y reproducibilidad del método.
# - Adecuación para imágenes de alta resolución.
# - Facilidad de integración en flujos geoespaciales automáticos.
#
# **Limitaciones:**
# - Sensibilidad al umbral de similitud.
# - Requiere calibración según condiciones de iluminación y ruido.
# - Mayor carga computacional en procesos multitemporales.
#
# **Aplicaciones sugeridas:**
# - Delimitación automática de parcelas agrícolas.
# - Seguimiento de estrés hídrico o nutricional.
# - Entrenamiento de modelos de IA explicable para monitoreo agrícola.
#
# ---
#
# ## Conclusiones
#
# 1. El método **Region Growing** ofrece un equilibrio óptimo entre simplicidad y efectividad para segmentación basada en homogeneidad.
# 2. Su combinación con K-Means permite **automatizar la selección de semillas**, incrementando la precisión espacial y reduciendo sobresegmentación.
# 3. Los resultados sobre imágenes Sentinel-2 confirman su utilidad para **detección de vigor vegetal y análisis de parcelas**.
# 4. La propuesta híbrida mantiene **transparencia interpretativa**, lo que favorece su uso en contextos científicos y productivos.
# 5. Futuras mejoras incluirán calibración dinámica de umbrales, fusión jerárquica de regiones y análisis multitemporal para series agrícolas.
#
# ---
#
# ## Referencias
#
# - Adams, R., & Bischof, L. (1994). *Seeded region growing*. IEEE Transactions on Pattern Analysis and Machine Intelligence, 16(6), 641–647.
# - Baatz, M., & Schäpe, A. (2000). *Multiresolution segmentation—An optimization approach for high-quality multi-scale image segmentation*. In *Angewandte Geographische Informationsverarbeitung XII* (pp. 12–23).
# - Gonzalez, R. C., & Woods, R. E. (2018). *Digital Image Processing* (4th ed.). Pearson.
# - Haralick, R. M., & Shapiro, L. G. (1985). *Image segmentation techniques*. Computer Vision, Graphics, and Image Processing, 29(1), 100–132.
# - Pavlidis, T. (1977). *Structural pattern recognition*. Springer-Verlag.
# - Pham, D. L., Xu, C., & Prince, J. L. (2000). *Current methods in medical image segmentation*. Annual Review of Biomedical Engineering, 2, 315–337.
# - Szeliski, R. (2022). *Computer Vision: Algorithms and Applications* (2nd ed.). Springer.
# - Tilton, J. C. (1998). *Image segmentation by region growing and merging*. NASA Technical Report, Goddard Space Flight Center.
# - Otsu, N. (1979). *A threshold selection method from gray-level histograms*. IEEE Transactions on Systems, Man, and Cybernetics, 9(1), 62–66.
# - Phinn, S., Roelfsema, C., & Dekker, A. (2018). *Remote sensing of vegetation and crops*. CRC Press.
